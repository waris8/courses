# %%
import numpy as np

# %%
import mujoco
import mediapy as media
import matplotlib.pyplot as plt

a = np.cos(np.deg2rad(60))
a
# Out:
# 0.5000000000000001

# %%
arr = []
omega = 0.1
r = 3
for i in range(1000):
    x = r*(1+np.cos(i*0.1*3))
    y = r*(1+np.sin(i*0.1*3))
    arr.append([x,y])
    
f = np.array(arr)
print(f)
plt.plot(f[:,0], f[:,1])
# Out:
# [[6.         3.        ]
#  [5.86600947 3.88656062]
#  [5.47600684 4.69392742]
#  ...
#  [0.60938661 1.18755204]
#  [1.25177479 0.56202777]
#  [2.05032672 0.15428029]]
